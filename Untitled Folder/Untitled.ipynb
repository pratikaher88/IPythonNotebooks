# %%
import json
import pandas as pd
import numpy as np
file = 'dexp2'
with open(file) as train_file:
    dict_train = json.load(train_file)

# %%
# print(dict_train)

dict_train = pd.io.json.json_normalize(dict_train)

train = pd.DataFrame.from_dict(dict_train)

# %%
dataf=train[['barrier_report.what_went_wrong','webpage_reported']]

# %%
datf = dataf.loc[dataf['barrier_report.what_went_wrong'].str.split().str.len() > 1 ]
datf
# Out:
#                         barrier_report.what_went_wrong  \
# 9                                             this yes
# 10   The report send button was a little hard to find.
# 11                                          small font
# 16                               pdf is not accessible
# 18                                     couldnt find it
# 31                                could not find POIs.
# 36   The text below "Get in touch" is not readable ...
# 37                                the font is to small
# 38                                    it did not work.
# 39                                     font too small.
# 40                                         Mikael test
# 41                                         Yellow one.
# 43                                testing for tooltips
# 45   This window should appear next to the PBT button.
# 47                   This input field should be wider.
# 50                                   Only testing now.
# 52                            I want automatic testing
# 53   The first question "What were you trying to do...
# 54                                   link did not work
# 55   Layout and design suggestions: \r\n1. Position...
# 56   Thinking about the state of the modal window.....
# 57                                cannot read document
# 58   I received the confirmation email for my repor...
# 62   On http://epbt.eu/start_report/ the keyboard f...
# 65                                          Ugly color
# 66        regjeringen.no does not generate ATT result?
# 67                                  Tingtun.no example
# 70                                            ups TEST
# 72                                            New test
# 78                                            2nd test
# 85                            Test for PBT development
# 86                                              A test
# 87                                       An other test
# 89                                      a test comment
# 91   I would love to see the automatic test of this...
# 92                      testing automatic testing tool
# 94    This automatic test should have an better score.
# 95                        Automatic testing tool test.
# 96                    language markup seems confusing.
# 97                             Test issue presentation
# 98                               The font is too small
# 100                                       Just testing
# 104                      The color should be brighter.
# 112                                 Great Barrier Reef
# 113                               Well it may not work
# 114                  I need larger fonts on this page.
# 116                                 font to small min.
# 117                               Hello,  Mike testing
# 120          I am not able to press the search button.
# 123                                             test 2
# 125  The contrast of the text to background in the ...
# 126                    Image is not clearly described.
# 127                    Image is not clearly described.
# 128                  Does not work with screen reader.
# 131                          screen reader not working
#
#                   webpage_reported
# 9    http://178.79.181.86/tingtun/
# 10   http://178.79.181.86/tingtun/
# 11   http://178.79.181.86/tingtun/
# 16   http://178.79.181.86/tingtun/
# 18   http://178.79.181.86/tingtun/
# 31   http://178.79.181.86/tingtun/
# 36   http://178.79.181.86/tingtun/
# 37   http://178.79.181.86/tingtun/
# 38   http://178.79.181.86/tingtun/
# 39   http://178.79.181.86/tingtun/
# 40     http://www.epbt.eu/tingtun/
# 41     http://www.epbt.eu/tingtun/
# 43     http://www.epbt.eu/tingtun/
# 45     http://www.epbt.eu/tingtun/
# 47     http://www.epbt.eu/tingtun/
# 50     http://www.epbt.eu/tingtun/
# 52         http://epbt.eu/tingtun/
# 53         http://epbt.eu/tingtun/
# 54         http://epbt.eu/tingtun/
# 55         http://epbt.eu/tingtun/
# 56         http://epbt.eu/tingtun/
# 57         http://epbt.eu/tingtun/
# 58         http://epbt.eu/tingtun/
# 62         http://epbt.eu/tingtun/
# 65
# 66
# 67         http://epbt.eu/tingtun/
# 70         http://epbt.eu/tingtun/
# 72         http://epbt.eu/tingtun/
# 78     http://epbt.eu/finished/78/
# 85   http://epbt.eu/government-no/
# 86   http://epbt.eu/government-se/
# 87   http://epbt.eu/government-no/
# 89         http://epbt.eu/tingtun/
# 91   http://epbt.eu/government-se/
# 92         http://epbt.eu/tingtun/
# 94         http://epbt.eu/tingtun/
# 95   http://epbt.eu/government-no/
# 96   http://epbt.eu/government-no/
# 97   http://epbt.eu/government-no/
# 98   http://epbt.eu/government-no/
# 100        http://epbt.eu/tingtun/
# 104  http://epbt.eu/government-no/
# 112  http://epbt.eu/government-no/
# 113  http://epbt.eu/government-no/
# 114  http://epbt.eu/government-no/
# 116  http://epbt.eu/government-no/
# 117  http://epbt.eu/government-no/
# 120  http://epbt.eu/government-se/
# 123        http://epbt.eu/tingtun/
# 125  http://epbt.eu/government-se/
# 126  http://epbt.eu/government-no/
# 127  http://epbt.eu/government-no/
# 128  http://epbt.eu/government-no/
# 131  http://epbt.eu/government-no/

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 20]

# %%
datf[['webpage_reported']].apply(pd.value_counts).plot(kind='bar', subplots=True)
plt.show()

# %%
datf[['barrier_report.what_went_wrong']].apply(pd.value_counts).plot(kind='bar', subplots=True)
plt.show()

# %%
df=datf

# %%
df=df[df['barrier_report.what_went_wrong'].str.len() > 0]
df=df[df['webpage_reported'].str.len()>0]

# %%
df['barrier_report.what_went_wrong'] = df['barrier_report.what_went_wrong'].astype(str).str.lower()

# %%
df['Counts']=df.groupby(['barrier_report.what_went_wrong'])['webpage_reported'].transform('count')

# %%
df=df.sort_values('Counts',ascending=False)

# %%
df=df.drop_duplicates().reset_index(drop=True)

# %%
df=df.sort_values('webpage_reported')

# %%
df
# Out:
#                        barrier_report.what_went_wrong  \
# 29                              pdf is not accessible
# 1                                            this yes
# 35                                    font too small.
# 34                                   it did not work.
# 33                               the font is to small
# 32  the text below "get in touch" is not readable ...
# 31                               could not find pois.
# 30                                    couldnt find it
# 28                                         small font
# 26  the report send button was a little hard to find.
# 14                                           2nd test
# 19                               hello,  mike testing
# 0                     image is not clearly described.
# 24                           test for pbt development
# 18                                 font to small min.
# 23                  does not work with screen reader.
# 17                  i need larger fonts on this page.
# 51                          screen reader not working
# 15                                 great barrier reef
# 13                      the color should be brighter.
# 16                               well it may not work
# 4                                       an other test
# 12                              the font is too small
# 11                            test issue presentation
# 9                        automatic testing tool test.
# 10                   language markup seems confusing.
# 6   i would love to see the automatic test of this...
# 3                                              a test
# 22  the contrast of the text to background in the ...
# 20          i am not able to press the search button.
# 50                                 tingtun.no example
# 49  on http://epbt.eu/start_report/ the keyboard f...
# 48  i received the confirmation email for my repor...
# 47                               cannot read document
# 46  thinking about the state of the modal window.....
# 45  layout and design suggestions: \r\n1. position...
# 44                                  link did not work
# 43  the first question "what were you trying to do...
# 42                           i want automatic testing
# 25                                           new test
# 2                                        just testing
# 21                                             test 2
# 5                                      a test comment
# 7                      testing automatic testing tool
# 8    this automatic test should have an better score.
# 27                                           ups test
# 40                  this input field should be wider.
# 41                                  only testing now.
# 38                               testing for tooltips
# 37                                        yellow one.
# 36                                        mikael test
# 39  this window should appear next to the pbt button.
#
#                  webpage_reported  Counts
# 29  http://178.79.181.86/tingtun/       1
# 1   http://178.79.181.86/tingtun/       1
# 35  http://178.79.181.86/tingtun/       1
# 34  http://178.79.181.86/tingtun/       1
# 33  http://178.79.181.86/tingtun/       1
# 32  http://178.79.181.86/tingtun/       1
# 31  http://178.79.181.86/tingtun/       1
# 30  http://178.79.181.86/tingtun/       1
# 28  http://178.79.181.86/tingtun/       1
# 26  http://178.79.181.86/tingtun/       1
# 14    http://epbt.eu/finished/78/       1
# 19  http://epbt.eu/government-no/       1
# 0   http://epbt.eu/government-no/       2
# 24  http://epbt.eu/government-no/       1
# 18  http://epbt.eu/government-no/       1
# 23  http://epbt.eu/government-no/       1
# 17  http://epbt.eu/government-no/       1
# 51  http://epbt.eu/government-no/       1
# 15  http://epbt.eu/government-no/       1
# 13  http://epbt.eu/government-no/       1
# 16  http://epbt.eu/government-no/       1
# 4   http://epbt.eu/government-no/       1
# 12  http://epbt.eu/government-no/       1
# 11  http://epbt.eu/government-no/       1
# 9   http://epbt.eu/government-no/       1
# 10  http://epbt.eu/government-no/       1
# 6   http://epbt.eu/government-se/       1
# 3   http://epbt.eu/government-se/       1
# 22  http://epbt.eu/government-se/       1
# 20  http://epbt.eu/government-se/       1
# 50        http://epbt.eu/tingtun/       1
# 49        http://epbt.eu/tingtun/       1
# 48        http://epbt.eu/tingtun/       1
# 47        http://epbt.eu/tingtun/       1
# 46        http://epbt.eu/tingtun/       1
# 45        http://epbt.eu/tingtun/       1
# 44        http://epbt.eu/tingtun/       1
# 43        http://epbt.eu/tingtun/       1
# 42        http://epbt.eu/tingtun/       1
# 25        http://epbt.eu/tingtun/       1
# 2         http://epbt.eu/tingtun/       1
# 21        http://epbt.eu/tingtun/       1
# 5         http://epbt.eu/tingtun/       1
# 7         http://epbt.eu/tingtun/       1
# 8         http://epbt.eu/tingtun/       1
# 27        http://epbt.eu/tingtun/       1
# 40    http://www.epbt.eu/tingtun/       1
# 41    http://www.epbt.eu/tingtun/       1
# 38    http://www.epbt.eu/tingtun/       1
# 37    http://www.epbt.eu/tingtun/       1
# 36    http://www.epbt.eu/tingtun/       1
# 39    http://www.epbt.eu/tingtun/       1

# %%
df.to_json('report.json', orient='records', lines=True)

# %%
df['barrier_report.what_went_wrong']
# Out:
# 29                                pdf is not accessible
# 1                                              this yes
# 35                                      font too small.
# 34                                     it did not work.
# 33                                 the font is to small
# 32    the text below "get in touch" is not readable ...
# 31                                 could not find pois.
# 30                                      couldnt find it
# 28                                           small font
# 26    the report send button was a little hard to find.
# 14                                             2nd test
# 19                                 hello,  mike testing
# 0                       image is not clearly described.
# 24                             test for pbt development
# 18                                   font to small min.
# 23                    does not work with screen reader.
# 17                    i need larger fonts on this page.
# 51                            screen reader not working
# 15                                   great barrier reef
# 13                        the color should be brighter.
# 16                                 well it may not work
# 4                                         an other test
# 12                                the font is too small
# 11                              test issue presentation
# 9                          automatic testing tool test.
# 10                     language markup seems confusing.
# 6     i would love to see the automatic test of this...
# 3                                                a test
# 22    the contrast of the text to background in the ...
# 20            i am not able to press the search button.
# 50                                   tingtun.no example
# 49    on http://epbt.eu/start_report/ the keyboard f...
# 48    i received the confirmation email for my repor...
# 47                                 cannot read document
# 46    thinking about the state of the modal window.....
# 45    layout and design suggestions: \r\n1. position...
# 44                                    link did not work
# 43    the first question "what were you trying to do...
# 42                             i want automatic testing
# 25                                             new test
# 2                                          just testing
# 21                                               test 2
# 5                                        a test comment
# 7                        testing automatic testing tool
# 8      this automatic test should have an better score.
# 27                                             ups test
# 40                    this input field should be wider.
# 41                                    only testing now.
# 38                                 testing for tooltips
# 37                                          yellow one.
# 36                                          mikael test
# 39    this window should appear next to the pbt button.
# Name: barrier_report.what_went_wrong, dtype: object

# %%
print(list(df['barrier_report.what_went_wrong']))
# Out:
# ['pdf is not accessible', 'this yes', 'font too small.', 'it did not work.', 'the font is to small', 'the text below "get in touch" is not readable to me, due to contrast deficiency.', 'could not find pois.', 'couldnt find it', 'small font', 'the report send button was a little hard to find.', '2nd test', 'hello,  mike testing', 'image is not clearly described.', 'test for pbt development', 'font to small min.', 'does not work with screen reader.', 'i need larger fonts on this page.', 'screen reader not working', 'great barrier reef', 'the color should be brighter.', 'well it may not work', 'an other test', 'the font is too small', 'test issue presentation', 'automatic testing tool test.', 'language markup seems confusing.', 'i would love to see the automatic test of this page.', 'a test', 'the contrast of the text to background in the search window is to low.', 'i am not able to press the search button.', 'tingtun.no example', 'on http://epbt.eu/start_report/ the keyboard focus on the emoticons is still not visible. it should look the same as the mouse focus indicator.', 'i received the confirmation email for my report.\r\nthe from addess is: root@tt0.s.tingtun.no\r\nplease change.', 'cannot read document', 'thinking about the state of the modal window...\r\nwhat i did: i reported a barrier and continue using the page and find another problem so i hit the reporting button again.\r\nwhat i expect: to see the start view of the modal window.\r\nwhat is shown: to message that a report was submitted.', 'layout and design suggestions: \r\n1. position of the checkbox before the sentence "i want to send ..."\r\n2. style back-link to look like a button.\r\n3. more space above and between the back and send-button', 'link did not work', 'the first question "what were you trying to do?" is missing. the two questions work well in combination. if we use only one question, it should be something like "please discribe the accessibility problem you encountered."', 'i want automatic testing', 'new test', 'just testing', 'test 2', 'a test comment', 'testing automatic testing tool', 'this automatic test should have an better score.', 'ups test', 'this input field should be wider.', 'only testing now.', 'testing for tooltips', 'yellow one.', 'mikael test', 'this window should appear next to the pbt button.']
