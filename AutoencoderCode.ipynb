# %%
# from keras.layers.core import Dense
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
# from keras.layers import Input
# from keras.models import Model

# %%
seed = 9
np.random.seed(seed)

# %%
dataset = pd.read_csv('generated_fuzzified_access_data.csv', delimiter=',')

# split into input and output variables
X = dataset.loc[:,["data_requested", "location_of_access", "time_of_access", "emergency", "previous_history"]]

# split the data into training (67%) and testing (33%)
(x_train, x_test, y_train, y_test) = train_test_split(X, dataset.access_granted, test_size=0.33, random_state=seed)

# %%
x_test
# Out:
#         data_requested  location_of_access  time_of_access  emergency  \
# 297061             1.0                 0.5            1.00          0
# 202917             1.0                 1.0            1.00          0
# 711886             0.1                 0.0            1.00          0
# 171576             1.0                 1.0            1.00          0
# 409514             1.0                 0.5            0.11          0
# 182702             1.0                 1.0            1.00          0
# 79928              1.0                 1.0            1.00          0
# 583218             1.0                 1.0            1.00          0
# 562350             0.5                 1.0            0.00          1
# 687057             0.1                 1.0            0.89          0
# 805739             0.1                 0.0            1.00          0
# 108834             1.0                 1.0            1.00          0
# ...

# %%
inputs = Input(shape=(5, ))
h = Dense(2, activation='sigmoid')(inputs)
outputs = Dense(5)(h)

model = Model(input=inputs, output=outputs)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train, x_train,
    batch_size=1024,
    epochs=30,
    )
# Out:
# /Users/siddhantgada/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
# Epoch 1/30
# 575128/575128 [==============================] - 2s 3us/step - loss: 7.7489 - acc: 0.3196
# Epoch 2/30
# 575128/575128 [==============================] - 2s 3us/step - loss: 7.7106 - acc: 0.3378
# Epoch 3/30
# 575128/575128 [==============================] - 2s 3us/step - loss: 7.6950 - acc: 0.3433
# Epoch 4/30
#  - 2s 3us/step - loss: 7.6933 - acc: 0.3433
# Epoch 5/30
# 575128/575128 [==============================] - 2s 3us/step - loss: 7.6932 - acc: 0.3433
# Epoch 6/30
# 575128/575128 [==============================] - 2s 3us/step - loss: 7.6932 - acc: 0.3433
# Epoch 7/30
# 575128/575128 [==============================] - 2s 3us/step - loss: 7.6932 - acc: 0.3433
# Epoch 8/30
# 575128/575128 [==============================] - 2s 3us/step - loss: 7.6932 - acc: 0.3433
# ...

# %%
h.trainable=False


# trying to add last sigmoid layer
outputs = Dense(1, activation='sigmoid')(h)

model = Model(input=inputs, output=outputs)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train,
    batch_size=1024,
    epochs=30,
    validation_data=(x_test,y_test))
# Out:
# /Users/siddhantgada/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
# Train on 575128 samples, validate on 283272 samples
# Epoch 1/30
# 575128/575128 [==============================] - 2s 3us/step - loss: 0.4261 - acc: 0.7981 - val_loss: 0.4050 - val_acc: 0.7987
# Epoch 2/30
# 575128/575128 [==============================] - 1s 2us/step - loss: 0.3894 - acc: 0.8003 - val_loss: 0.3721 - val_acc: 0.8094
# Epoch 3/30
# 575128/575128 [==============================] - 1s 2us/step - loss: 0.3610 - acc: 0.8348 - val_loss: 0.3471 - val_acc: 0.8595
# Epoch 4/30
# 575128/575128 [==============================] - 1s 3us/step - loss: 0.3391 - acc: 0.8638 - val_loss: 0.3276 - val_acc: 0.8690
# Epoch 5/30
# 575128/575128 [==============================] - 1s 3us/step - loss: 0.3225 - acc: 0.8725 - val_loss: 0.3137 - val_acc: 0.8776
# Epoch 6/30
# ...

# %%
model.predict()
